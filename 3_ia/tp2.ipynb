# %% [markdown]
# # TP 2 : Analyse d'un LLM et benchmarking
#
# ## 1. Analyse d'un LLM en local
#
# ### 1.1 Installation
#
# #### 1.1.1 Configuration de VS Code
#
# Voir `tp2.pptx` sur Moodle.
#
# #### 1.1.2 Installation des librairies

# %%
# Installation des bibliothèques  (Ne faire qu'une fois)
# %pip install transformers accelerate huggingface_hub
# %pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (4.57.6)
# Requirement already satisfied: accelerate in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (1.10.1)
# Requirement already satisfied: huggingface_hub in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (0.36.2)
# Requirement already satisfied: requests in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: numpy>=1.17 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: packaging>=20.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (26.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: psutil in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from accelerate) (2.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from huggingface_hub) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from huggingface_hub) (1.3.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2026.2.25)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.11)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (8.1.8)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: comm>=0.1.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: decorator in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: matplotlib-inline in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: typing-extensions in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: exceptiongroup in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: stack-data in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: pure-eval in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/hanyang/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 1.1.3 Vérification de l'environnement

# %%
# Vérification de l'environnement
import torch
import transformers

print(f"PyTorch version   : {torch.__version__}")
print(f"Transformers ver  : {transformers.__version__}")
print(f"CUDA disponible   : {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU               : {torch.cuda.get_device_name(0)}")
    total_mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"VRAM              : {total_mem:.1f} GB")
else:
    print("⚠️  Pas de GPU détecté — le CPU sera utilisé (plus lent)")
# Out:
# /Users/hanyang/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# PyTorch version   : 2.8.0
# Transformers ver  : 4.57.6
# CUDA disponible   : False
# ⚠️  Pas de GPU détecté — le CPU sera utilisé (plus lent)

# %% [markdown]
# ### 1.2 Qwen
#
# #### 1.2.1 Qwen/Qwen3-0.6B-Base
#
# Nous étudions d'abord un modèle LLM brut, dont l'identifiant modèle est : `Qwen/Qwen3-0.6B-Base`
#
# 1. Expliquer les différents parties de l'identifiant. Pourquoi utilisons-nous la version `0.6B` dans ce TP ?
# 2. Tester le code ci-dessous. Que fait-il ?
# 3. Commenter chaque ligne du code pour comprendre son rôle.
# 4. Tester différents prompts.
# 5. Changer le paramètre `temperature`. Qu'est-ce que vous observez ? Que fait concrètement ce paramètre ?
# 6. Et si vous remplacez l'argument `temperature` par `do_sample=False` et que vous exécutez le bloc le deux fois de suite ?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "Qwen/Qwen3-0.6B-Base"

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device="mps",
    torch_dtype=torch.float32
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Device set to use mps

# %%
prompt = "Qu'est-ce que l'intelligence artificielle ?'"
# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=120,
    return_full_text=True,
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)
# Out:
# RÉPONSE
#
# Qu'est-ce que l'intelligence artificielle ?' L'intelligence artificielle, ou IA, est un domaine de recherche et de développement qui étudie comment les ordinateurs peuvent acquérir des capacités de raisonnement et de prise de décision similaires à celles des êtres humains. Elle permet aux ordinateurs de faire des décisions basées sur des données, d'analyser des données, d'apprendre de l'expérience, et d'interagir avec des utilisateurs.
#
# ### Définition
# - **Objectifs**: L'intelligence artificielle cherche à créer des syst

# %% [markdown]
# #### 1.2.2 Qwen/Qwen3-0.6B
#
# Nous utilisons maintenant la version sans `Base` de `Qwen3-0.6B-Base`.
#
# 1. Que signifie ce changement dans l'identifiant ?
# 2. Tester le code ci-dessous. Qu'est-ce que est différent ?
# 3. Commenter les nouvelles lignes pour expliquer leurs rôles ?
# 3. Tester différents `content` pour `user`.
# 4. Décommenter les lignes `system`. Tester différents `content`.
# 5. Analysez le contenu du prompt. Quels sont ses différents éléments et que veulent-ils dire ?
# 6. Et que se passe-t-il si vous remplacez le `prompt` par une question ou un texte quelconque ?
# 7. Que se passe-t-il avec `enable_thinking=True` ?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "Qwen/Qwen3-0.6B" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device="mps",
    torch_dtype=torch.float32
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use mps

# %%
# ---- Début des nouvelles lignes
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer that warns the user of the dangers of technology."},
    {"role": "user",   "content": "Qu'est-ce que l'intelligence artificielle ?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=False
)

# prompt = "Ainsi donc"
# ---- Fin des nouvelles lignes

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=120,
    return_full_text=False, # ne pas retourner pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)

# %% [markdown]
# ### 1.3 TinyLlama
#
# Voici un autre modèle : `TinyLlama/TinyLlama-1.1B-Chat-v1.0`
#
# 1. Tester quelques questions et comparer les réponses à celles de Qwen
# 2. Tester différents paramètres.
# 2. Que pensez-vous de la capacité de TinyLlama à suivre les instructions `system`?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    device=-1,
    torch_dtype=torch.float32
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cpu

# %%
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You answer with a json."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer that warns the user of the dangers of technology."},
    {"role": "user",   "content": "Qu'est-ce que l'intelligence artificielle ?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
)

# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=120,
    return_full_text=False, # ne retourne pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)

# %% [markdown]
# ### 1.4 SmolLM
#
# 1. Tester quelques questions et comparer les réponses à celles de Qwen et TinyLlama.
# 2. Tester différents paramètres.
# 2. Que pensez-vous de la capacité de SmolLM à suivre les instructions `system`?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "HuggingFaceTB/SmolLM2-1.7B-Instruct" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    device=-1,
    torch_dtype=torch.float32
)

# %%
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You answer with a json."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer who warns the user of the dangers of technology."},
    {"role": "user",   "content": "Qu'est-ce que l'intelligence artificielle ?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=False
)

# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=120,
    return_full_text=False, # ne pas retourner pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)

# %% [markdown]
# ### 1.5 Pour aller plus loin
#
# * Tester `HuggingFaceTB/SmolLM3-3B` (plus lent)
# * Explorer d'autres modèles sur [HuggingFace](https://huggingface.co)

# %% [markdown]
# ## 2 Benchmarking
#
# ### 2.1 MMLU
#
# #### 2.1.1 Télécharger et explorer les données du benchmark
#
# 1. Exécuter le code pour télécharger la banque de question du MMLU sur les mathématiques élémentaires.

# %%
# %pip install datasets # ne faire qu'une fois

# %%
from datasets import load_dataset
ds_elementary_mathematics = load_dataset("cais/mmlu", "elementary_mathematics")

# %% [markdown]
# 2. Analyser la structure du jeu de données
# 3. Explorer quelques questions du benchmark

# %%
ds_elementary_mathematics
# ds_elementary_mathematics['dev'][0]

# %% [markdown]
# 4. Explorer la liste des sujets abordés par le MMLU
# 5. Explorer les questions de quelques autres sujets

# %%
from datasets import get_dataset_config_names

subjects = get_dataset_config_names("cais/mmlu")
print(f"{len(subjects)} matières disponibles :\n")
for s in sorted(subjects):
    print(f"  {s}")

# %% [markdown]
# #### 2.1.2 Tester avec des modèles locaux
#
# 1. Tester quelques questions avec différents modèles locaux

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "HuggingFaceTB/SmolLM2-1.7B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device=-1,
    torch_dtype=torch.float32
)

# %%
question = ds_elementary_mathematics['dev'][0]['question'] + "\n" + \
    " | ".join(f"{chr(65+i)}. {c}" for i, c in enumerate(ds_elementary_mathematics['dev'][0]['choices'])) + \
    "\n Only reply with a letter."


messages = [
    {"role": "system", "content": "Answer with a single letter only (A, B, C or D):"},
    {"role": "user",   "content": question}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=True
)

result = gen(
    prompt,    
    do_sample=False, # Modèle déterministique
    max_new_tokens=1000,
    return_full_text=False,
)

print(
    result[0]["generated_text"]
)

# %% [markdown]
# 2. Testez le modèle plus systématiquement sur plusieurs questions, en vous aidant du code ci-dessous.
# 3. Testez avec différents benchmarks et paramètre de modèles et notez vos impressions.
# 4. Pourquoi est-ce que `do_sample=False` ?

# %%
import json, re

results = []

for item in ds_elementary_mathematics['dev']:
    question_text = item['question'] + "\n" + \
        " | ".join(f"{chr(65+i)}. {c}" for i, c in enumerate(item['choices'])) + \
            "\n\nReply with a single letter: A, B, C or D. Nothing else."
    messages = [
        {"role": "system", "content": "Reply with a single letter: A, B, C or D. Nothing else."},
        {"role": "user", "content": question_text}
    ]
    
    prompt = tokenizer.apply_chat_template(messages, tokenize=False,
                                            add_generation_prompt=True,
                                            enable_thinking=False)
    
    result = gen(prompt, do_sample=False, max_new_tokens=10,
                 return_full_text=False)
    
    response = result[0]["generated_text"].strip()
    match = re.search(r'\b([A-D])\b', response)
    answer = ord(match.group(1)) - ord('A') if match else -1
    results.append(answer)

print(results)

# Comparer avec les vraies réponses
correct = [item['answer'] for item in ds_elementary_mathematics['dev']]
accuracy = sum(p == c for p, c in zip(results, correct)) / len(correct)
print(f"Accuracy : {accuracy:.1%}")

# %% [markdown]
# #### 2.2 Tester avec les modèles majeurs
#
# 1. Essayer de tester des modèles majeurs sur le benchmark et de calculer le taux de succès.
# 2. Comparer vos scores aux résultats sur les leaderboards de quelques sites de référence.
# 3. Nommer quelques limitations de votre test.
#
# ### 2.3 Autres benchmarks (Lecture 3, pour le mardi 10 Mars)
#
# Il existent de nombreux autres benchmarks.
#
# 1. Faites une recherche pour en trouver 2 ou 3, les plus variés possibles. Vous pouvez essayer de trouver des benchmarks qui testent des sujets qui vous intéressent (science, programmation, mathématiques, écriture de fiction, etc.).
# 2. Créer un petit tableau avec des informations générales sur les benchmarks.
# 3. Quelles compétences des IA mesurent vos benchmarks ?
# 4. Trouver quelques questions et regardez les réponses des modèles locaux, ainsi que ceux des grands modèles. Quelles sont vos impressions ?
# 5. Cherchez les résultats des modèles sur vos benchmarks sur des sites de références. Comment ont évolué les scores des meilleurs modèles depuis la publication du benchmark.
