# %% [markdown]
# # TP 2 : Analyse d'un LLM et benchmarking
#
# ## 1. Analyse d'un LLM en local
#
# ### 1.1 Installation
#
# #### 1.1.1 Configuration de VS Code
#
# Voir `tp2.pptx` sur Moodle.
#
# #### 1.1.2 Installation des librairies

# %%
# Installation des bibliothèques  (Ne faire qu'une fois)
# %pip install transformers accelerate huggingface_hub
# %pip install ipywidgets
# Out:
# Collecting transformers
#   Downloading transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting numpy>=1.17 (from transformers)
#   Downloading numpy-2.4.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from transformers) (26.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2026.2.28-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting filelock>=3.10.0 (from huggingface_hub)
#   Downloading filelock-3.25.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface_hub)
#   Downloading hf_xet-1.3.2-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface_hub)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.1.0 (from huggingface_hub)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: psutil in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from accelerate) (7.2.2)
# Collecting torch>=2.0.0 (from accelerate)
#   Downloading torch-2.10.0-2-cp313-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting setuptools (from torch>=2.0.0->accelerate)
#   Downloading setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->accelerate)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->accelerate)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch>=2.0.0->accelerate)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->accelerate)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.0.0->accelerate)
#   Downloading markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting click>=8.2.1 (from typer->transformers)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.3.0-py3-none-any.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 29.9 MB/s  0:00:00eta 0:00:01
# Downloading huggingface_hub-1.5.0-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 16.9 MB/s  0:00:00
# Downloading hf_xet-1.3.2-cp37-abi3-macosx_11_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 16.5 MB/s  0:00:00 eta 0:00:01
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 21.0 MB/s  0:00:00
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading filelock-3.25.0-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading numpy-2.4.2-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 18.5 MB/s  0:00:00 eta 0:00:01
# Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading regex-2026.2.28-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Downloading torch-2.10.0-2-cp313-none-macosx_11_0_arm64.whl (79.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 5.0 MB/s  0:00:15m0:00:0100:01m
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.5 MB/s  0:00:00 eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 7.9 MB/s  0:00:00 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 5.2 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.0 MB/s  0:00:00
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, typing-extensions, tqdm, sympy, shellingham, setuptools, safetensors, regex, pyyaml, numpy, networkx, mdurl, MarkupSafe, idna, hf-xet, h11, fsspec, filelock, click, certifi, annotated-doc, markdown-it-py, jinja2, httpcore, anyio, torch, rich, httpx, typer, huggingface_hub, tokenizers, accelerate, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33/33 [transformers] [transformers]ub]
# Successfully installed MarkupSafe-3.0.3 accelerate-1.13.0 annotated-doc-0.0.4 anyio-4.12.1 certifi-2026.2.25 click-8.3.1 filelock-3.25.0 fsspec-2026.2.0 h11-0.16.0 hf-xet-1.3.2 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-1.5.0 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.2 pyyaml-6.0.3 regex-2026.2.28 rich-14.3.3 safetensors-0.7.0 setuptools-82.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.10.0 tqdm-4.67.3 transformers-5.3.0 typer-0.24.1 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipywidgets) (9.11.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator>=5.1.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/pd56ngv/Documents/GitHub/oc25_hanyang/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 15.5 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.9 MB/s  0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 1.1.3 Vérification de l'environnement

# %%
# Vérification de l'environnement
import torch
import transformers

print(f"PyTorch version   : {torch.__version__}")
print(f"Transformers ver  : {transformers.__version__}")
print(f"CUDA disponible   : {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU               : {torch.cuda.get_device_name(0)}")
    total_mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"VRAM              : {total_mem:.1f} GB")
else:
    print("⚠️  Pas de GPU détecté — le CPU sera utilisé (plus lent)")
# Out:
# PyTorch version   : 2.10.0
# Transformers ver  : 5.3.0
# CUDA disponible   : False
# ⚠️  Pas de GPU détecté — le CPU sera utilisé (plus lent)

# %% [markdown]
# ### 1.2 Qwen
#
# #### 1.2.1 Qwen/Qwen3-0.6B-Base
#
# Nous étudions d'abord un modèle LLM brut, dont l'identifiant modèle est : `Qwen/Qwen3-0.6B-Base`
#
# 1. Expliquer les différents parties de l'identifiant. Pourquoi utilisons-nous la version `0.6B` dans ce TP ?
# 2. Tester le code ci-dessous. Que fait-il ?
# 3. Commenter chaque ligne du code pour comprendre son rôle.
# 4. Tester différents prompts.
# 5. Changer le paramètre `temperature`. Qu'est-ce que vous observez ? Que fait concrètement ce paramètre ?
# 6. Et si vous remplacez l'argument `temperature` par `do_sample=False` et que vous exécutez le bloc le deux fois de suite ?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "Qwen/Qwen3-0.6B-Base"

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device="mps",
    torch_dtype=torch.float32
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]

# %%
prompt = "Comment cuir un chat?"
# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=1.0,
    max_new_tokens=200,
    return_full_text=True,
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)
# Out:
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# RÉPONSE
#
# Comment cuir un chat? Comment un chat est-ce que ça marche dans ce monde? Est-ce que vous avez été dans un chat en réalité virtuelle? Quand veux-tu faire un chat avec un chat?
#
# Pour cuit de chat, commencez par en prendre une chose légère, dans une cuvette, et à un point en dessous. Une fois la pochette ou dague de chat bien tapissée, appliquez une cuisson rapide par la tige. Faites couler des heures durant un temps suffisamment chaud, puis retirez le chat de sa pochette et placez en serviette de table. Lorsque le chat est froid, lavez-le légèrement, et fermez les lames du chat d’un coup. Le chat doit rester encore frais pendant une heure avant la perte de température. Il est important d'utiliser des chaussettes pour chauffer les joints avant l'utilisation de la pièce

# %% [markdown]
# #### 1.2.2 Qwen/Qwen3-0.6B
#
# Nous utilisons maintenant la version sans `Base` de `Qwen3-0.6B-Base`.
#
# 1. Que signifie ce changement dans l'identifiant ?
# 2. Tester le code ci-dessous. Qu'est-ce que est différent ?
# 3. Commenter les nouvelles lignes pour expliquer leurs rôles ?
# 3. Tester différents `content` pour `user`.
# 4. Décommenter les lignes `system`. Tester différents `content`.
# 5. Analysez le contenu du prompt. Quels sont ses différents éléments et que veulent-ils dire ?
# 6. Et que se passe-t-il si vous remplacez le `prompt` par une question ou un texte quelconque ?
# 7. Que se passe-t-il avec `enable_thinking=True` ?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "Qwen/Qwen3-0.6B" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device="mps",
    torch_dtype=torch.float32
)
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# ---- Début des nouvelles lignes
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer that warns the user of the dangers of technology."},
    {"role": "user",   "content": "Comment faire un gateau?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=False
)

# prompt = "Ainsi donc"
# ---- Fin des nouvelles lignes

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=500,
    return_full_text=False, # ne pas retourner pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)
# Out:
# Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# RÉPONSE
#
# Pour faire un gateau, voici une méthode simple et pratique :
#
# ### 1. **Préparer les ingrédients :**
#    - **Miel** : 100–200 g
#    - **Beurre** : 150–200 g
#    - **Pâte de beurre** : 100 g (pour le glace)
#    - **Glace** : 150 g (pour le glace)
#    - **Céréales** : 150 g (ex. : riz, farine, farine, etc.)
#    - **Oeuf** : 1 à 2 œufs
#    - **Beurre** : 200 g (pour le glace)
#    - **Sel** et **poivre** : 10–20 g (pour le glace)
#    - **Sucre** : 10–20 g (pour le glace)
#    - **Moi** : 100–150 g (pour le glace)
#
# ### 2. **Mélanger les ingrédients :**
#    - **Mélanger les céréales et le beurre** avec le sel et le poivre.
#    - **Ajouter le miel** et le beurre (10–20 g) pour un mélange plus doux.
#    - **Ajouter l’oeuf** (1–2 œufs), et puis ajouter le beurre pour le glace.
#
# ### 3. **Faire le cake :**
#    - **Faire un fond de cake** : en pré-écrant la pâte au beurre sur une plaque de cuisson.
#    - **Faire le cake au four** : en feuilletant les 200–300 g de pâte sur une plaque de cuisson, en les couvrant de beurre, et en cuisant 15–20 minutes à 170°C.
#    - **Ajouter le glace** : pour finir, pour un glace plus doux, ajoutez 150 g de glace au fond du cake.
#
# ### 4. **Servir :**
#    - Servir le cake au frigo, ou le servir directement sur une table.
#
# ### Note :
# Si vous

# %% [markdown]
# ### 1.3 TinyLlama
#
# Voici un autre modèle : `TinyLlama/TinyLlama-1.1B-Chat-v1.0`
#
# 1. Tester quelques questions et comparer les réponses à celles de Qwen
# 2. Tester différents paramètres.
# 2. Que pensez-vous de la capacité de TinyLlama à suivre les instructions `system`?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    device=-1,
    torch_dtype=torch.float32
)
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You answer with a json."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer that warns the user of the dangers of technology."},
    {"role": "user",   "content": "comment faire des maths ?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
)

# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=1000,
    return_full_text=False, # ne retourne pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)
# Out:
# Both `max_new_tokens` (=1000) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# RÉPONSE
#
# Certainement! Les maths sont une pédagogie efficace et riche de contenus pour enseigner aux enfants, les adultes et les étudiants. Pour les enfants, c'est-à-dire, les enfants de 6 à 11 ans, on peut les utiliser pour comprendre les maths de base. Il y a plusieurs manières de faire des maths pour les enfants et les adultes.
#
# 1. Sous-traitances : on peut faire des maths sous-traitances, c'est-à-dire, des problèmes simples à réussir avec des points de référence pour les enfants. On peut alors envoyer les enfants pour réussir des examens maths ou pour faire des exercices.
#
# 2. Formateurs de maths : on peut faire des formations pour les enfants et les adultes. Ces formations sont généralement des programmes d'apprentissage et on peut les faire en ligne. Les formations sont souvent en ligne pour les enfants, car ils peuvent être en train de faire leurs cours et les formations peuvent être pratiquées sur le même ordinateur.
#
# 3. Formations en ligne : on peut également faire des formations en ligne, c'est-à-dire, des cours en ligne pour les adultes et les étudiants. Les formations sont souvent en ligne, car elles peuvent être pratiquées sans encombrement. Les formations en ligne peuvent être des cours pour les enfants et peuvent également utiliser des jeux numériques pour faire des exercices maths.
#
# 4. Formations en laboratoire : on peut également faire des formations en laboratoire pour les enfants. Les formations en laboratoire sont des formations pour les enfants qui peuvent faire des expériences pour comprendre les maths. Cela peut être en plein air ou dans une salle de laboratoire.
#
# En conclusions, l'utilisation de maths pour faire des maths pour enfants et les adultes est une pédagogie effective, riche et adaptée au niveau des enfants. Il y a plusieurs manières de faire des maths pour enfants et les adultes. Les formations sont également une manière efficace de faire des maths pour les enfants, et les formations en ligne sont également une façon efficace pour les adultes.

# %% [markdown]
# ### 1.4 SmolLM
#
# 1. Tester quelques questions et comparer les réponses à celles de Qwen et TinyLlama.
# 2. Tester différents paramètres.
# 2. Que pensez-vous de la capacité de SmolLM à suivre les instructions `system`?

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "HuggingFaceTB/SmolLM2-1.7B-Instruct" # utiliser le nouveau modèle

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    device=-1,
    torch_dtype=torch.float32
)
# Out:
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
messages = [
    # {"role": "system", "content": "You only answer with one word."},
    # {"role": "system", "content": "You answer with a json."},
    # {"role": "system", "content": "You are a pessimistic and poetic sci-fi writer who warns the user of the dangers of technology."},
    {"role": "user",   "content": "Qu'est-ce que un chien?"}
    # {"role": "user",   "content": "Ainsi donc"}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=False
)

# prompt = "Ainsi donc"

result = gen(
    prompt,
    temperature=0.7,
    max_new_tokens=1000,
    return_full_text=False, # ne pas retourner pas le prompt de l'utilisateur
)

print(
    "\nRÉPONSE\n\n" +
    result[0]["generated_text"]
)
# Out:
# Both `max_new_tokens` (=1000) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# RÉPONSE
#
# Un chien, en termes généraux, est une espèce de quadruped animale animale qui est encore en mesure de vivre et de naviguer dans le monde. On appelle chien ainsi un animal de famille, qui est connu pour ses aspects méconnants et son role comique dans la vie humaine. Le chien est généralement un animal d'habit et de manière quotidienne, appartenant aux espèces des carnivores. Ils ont besoin d'aliments supplémentaires pour vivre bien et ce qui les donne leur caractère spécial.

# %% [markdown]
# ### 1.5 Pour aller plus loin
#
# * Tester `HuggingFaceTB/SmolLM3-3B` (plus lent)
# * Explorer d'autres modèles sur [HuggingFace](https://huggingface.co)

# %% [markdown]
# ## 2 Benchmarking
#
# ### 2.1 MMLU
#
# #### 2.1.1 Télécharger et explorer les données du benchmark
#
# 1. Exécuter le code pour télécharger la banque de question du MMLU sur les mathématiques élémentaires.

# %%
# %pip install datasets # ne faire qu'une fois

# %%
from datasets import load_dataset
ds_elementary_mathematics = load_dataset("cais/mmlu", "elementary_mathematics")

# %% [markdown]
# 2. Analyser la structure du jeu de données
# 3. Explorer quelques questions du benchmark

# %%
ds_elementary_mathematics
# ds_elementary_mathematics['dev'][0]

# %% [markdown]
# 4. Explorer la liste des sujets abordés par le MMLU
# 5. Explorer les questions de quelques autres sujets

# %%
from datasets import get_dataset_config_names

subjects = get_dataset_config_names("cais/mmlu")
print(f"{len(subjects)} matières disponibles :\n")
for s in sorted(subjects):
    print(f"  {s}")

# %% [markdown]
# #### 2.1.2 Tester avec des modèles locaux
#
# 1. Tester quelques questions avec différents modèles locaux

# %%
from transformers import pipeline, AutoTokenizer
import torch

model_id = "HuggingFaceTB/SmolLM2-1.7B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)

gen = pipeline(
    "text-generation", 
    model=model_id,
    tokenizer=tokenizer, 
    device=-1,
    torch_dtype=torch.float32
)

# %%
question = ds_elementary_mathematics['dev'][0]['question'] + "\n" + \
    " | ".join(f"{chr(65+i)}. {c}" for i, c in enumerate(ds_elementary_mathematics['dev'][0]['choices'])) + \
    "\n Only reply with a letter."


messages = [
    {"role": "system", "content": "Answer with a single letter only (A, B, C or D):"},
    {"role": "user",   "content": question}
]

prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True,
    enable_thinking=True
)

result = gen(
    prompt,    
    do_sample=False, # Modèle déterministique
    max_new_tokens=1000,
    return_full_text=False,
)

print(
    result[0]["generated_text"]
)

# %% [markdown]
# 2. Testez le modèle plus systématiquement sur plusieurs questions, en vous aidant du code ci-dessous.
# 3. Testez avec différents benchmarks et paramètre de modèles et notez vos impressions.
# 4. Pourquoi est-ce que `do_sample=False` ?

# %%
import json, re

results = []

for item in ds_elementary_mathematics['dev']:
    question_text = item['question'] + "\n" + \
        " | ".join(f"{chr(65+i)}. {c}" for i, c in enumerate(item['choices'])) + \
            "\n\nReply with a single letter: A, B, C or D. Nothing else."
    messages = [
        {"role": "system", "content": "Reply with a single letter: A, B, C or D. Nothing else."},
        {"role": "user", "content": question_text}
    ]
    
    prompt = tokenizer.apply_chat_template(messages, tokenize=False,
                                            add_generation_prompt=True,
                                            enable_thinking=False)
    
    result = gen(prompt, do_sample=False, max_new_tokens=10,
                 return_full_text=False)
    
    response = result[0]["generated_text"].strip()
    match = re.search(r'\b([A-D])\b', response)
    answer = ord(match.group(1)) - ord('A') if match else -1
    results.append(answer)

print(results)

# Comparer avec les vraies réponses
correct = [item['answer'] for item in ds_elementary_mathematics['dev']]
accuracy = sum(p == c for p, c in zip(results, correct)) / len(correct)
print(f"Accuracy : {accuracy:.1%}")

# %% [markdown]
# #### 2.2 Tester avec les modèles majeurs
#
# 1. Essayer de tester des modèles majeurs sur le benchmark et de calculer le taux de succès.
# 2. Comparer vos scores aux résultats sur les leaderboards de quelques sites de référence.
# 3. Nommer quelques limitations de votre test.
#
# ### 2.3 Autres benchmarks (Lecture 3, pour le mardi 10 Mars)
#
# Il existent de nombreux autres benchmarks.
#
# 1. Faites une recherche pour en trouver 2 ou 3, les plus variés possibles. Vous pouvez essayer de trouver des benchmarks qui testent des sujets qui vous intéressent (science, programmation, mathématiques, écriture de fiction, etc.).
# 2. Créer un petit tableau avec des informations générales sur les benchmarks.
# 3. Quelles compétences des IA mesurent vos benchmarks ?
# 4. Trouver quelques questions et regardez les réponses des modèles locaux, ainsi que ceux des grands modèles. Quelles sont vos impressions ?
# 5. Cherchez les résultats des modèles sur vos benchmarks sur des sites de références. Comment ont évolué les scores des meilleurs modèles depuis la publication du benchmark.
